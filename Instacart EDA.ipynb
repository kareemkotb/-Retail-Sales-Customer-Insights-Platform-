-- %%
%sql
/* Total Orders */
select 
count(distinct(orders_order_id))
from instacart.default.silver_customers_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT(orders_order_id))</th></tr></thead><tbody><tr><td>131209</td></tr></tbody></table></div>

-- %%
/* Total Orders */
select 
count(distinct(orders_order_id))
from instacart.default.silver_customers_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT(orders_order_id))</th></tr></thead><tbody><tr><td>131209</td></tr></tbody></table></div>

-- %%
/* Total Customers */
select 
count(distinct(user_id))
from instacart.default.silver_customers_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT(user_id))</th></tr></thead><tbody><tr><td>131209</td></tr></tbody></table></div>

-- %%
/* Average Basket Size */
SELECT
(sum(orders_order_id) / sum(op_product_id)) as Average_Basket_Size
from instacart.default.silver_customers_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Average_Basket_Size</th></tr></thead><tbody><tr><td>66.76639076279535</td></tr></tbody></table></div>

-- %%
/* Top Products by Sales Count */
select
product_name,
count(*) as product_sales_count
from instacart.default.silver_customers_orders
group by product_name
order by product_sales_count desc
limit 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_name</th><th>product_sales_count</th></tr></thead><tbody><tr><td>Banana</td><td>18726</td></tr><tr><td>Bag of Organic Bananas</td><td>15480</td></tr><tr><td>Organic Strawberries</td><td>10894</td></tr><tr><td>Organic Baby Spinach</td><td>9784</td></tr><tr><td>Large Lemon</td><td>8135</td></tr><tr><td>Organic Avocado</td><td>7409</td></tr><tr><td>Organic Hass Avocado</td><td>7293</td></tr><tr><td>Strawberries</td><td>6494</td></tr><tr><td>Limes</td><td>6033</td></tr><tr><td>Organic Raspberries</td><td>5546</td></tr></tbody></table></div>

-- %%
/* Day of week Order Distribution */
select
count(orders_order_id) as total_orders,
order_dow
from instacart.default.silver_customers_orders
group by order_dow
order by total_orders desc;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th><th>order_dow</th></tr></thead><tbody><tr><td>324026</td><td>0</td></tr><tr><td>207279</td><td>6</td></tr><tr><td>205978</td><td>1</td></tr><tr><td>176910</td><td>5</td></tr><tr><td>160562</td><td>2</td></tr><tr><td>155481</td><td>4</td></tr><tr><td>154381</td><td>3</td></tr></tbody></table></div>

-- %%
/* Hourly Order Distribution */
select
count(orders_order_id) as total_orders,
order_hour_of_day
from instacart.default.silver_customers_orders
group by order_hour_of_day
order by total_orders desc;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th><th>order_hour_of_day</th></tr></thead><tbody><tr><td>119370</td><td>14</td></tr><tr><td>116198</td><td>15</td></tr><tr><td>114762</td><td>13</td></tr><tr><td>114119</td><td>11</td></tr><tr><td>111752</td><td>12</td></tr><tr><td>110479</td><td>10</td></tr><tr><td>110237</td><td>16</td></tr><tr><td>96944</td><td>17</td></tr><tr><td>93856</td><td>9</td></tr><tr><td>76522</td><td>18</td></tr><tr><td>67386</td><td>8</td></tr><tr><td>58175</td><td>19</td></tr><tr><td>40920</td><td>20</td></tr><tr><td>36302</td><td>7</td></tr><tr><td>34813</td><td>21</td></tr><tr><td>27319</td><td>22</td></tr><tr><td>16965</td><td>23</td></tr><tr><td>11847</td><td>6</td></tr><tr><td>9083</td><td>0</td></tr><tr><td>5626</td><td>1</td></tr><tr><td>3847</td><td>5</td></tr><tr><td>3226</td><td>2</td></tr><tr><td>2438</td><td>3</td></tr><tr><td>2431</td><td>4</td></tr></tbody></table></div>

-- %%
/* Customer Retention Rate */
select
if(order_number > 1, true, false) as repeat_customer,
count(distinct(user_id))
from instacart.default.silver_customers_orders
group by repeat_customer;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repeat_customer</th><th>count(DISTINCT(user_id))</th></tr></thead><tbody><tr><td>true</td><td>131209</td></tr></tbody></table></div>

-- %%
/* Customer Lifetime Orders (shows top 10 customers) */
select
max(order_number) as Max_Order,
user_id
from instacart.default.silver_customers_orders
group by user_id
order by max_order desc
limit 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Max_Order</th><th>user_id</th></tr></thead><tbody><tr><td>100</td><td>1428</td></tr><tr><td>100</td><td>786</td></tr><tr><td>100</td><td>1024</td></tr><tr><td>100</td><td>1683</td></tr><tr><td>100</td><td>310</td></tr><tr><td>100</td><td>210</td></tr><tr><td>100</td><td>690</td></tr><tr><td>100</td><td>313</td></tr><tr><td>100</td><td>1958</td></tr><tr><td>100</td><td>2405</td></tr></tbody></table></div>

-- %%
/* Departement Level Sales */
select
count(products_aisle_id) as total_products,
department_name
from instacart.default.silver_customers_orders
group by department_name
sort by total_products desc
limit 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_products</th><th>department_name</th></tr></thead><tbody><tr><td>409087</td><td>produce</td></tr><tr><td>217051</td><td>dairy eggs</td></tr><tr><td>118862</td><td>snacks</td></tr><tr><td>114046</td><td>beverages</td></tr><tr><td>100426</td><td>frozen</td></tr><tr><td>81242</td><td>pantry</td></tr><tr><td>48394</td><td>bakery</td></tr><tr><td>46799</td><td>canned goods</td></tr><tr><td>44291</td><td>deli</td></tr><tr><td>38713</td><td>dry goods pasta</td></tr></tbody></table></div>

-- %%
/* Aisle Level Sales */
select
count(products_aisle_id) as total_products,
aisle_name
from instacart.default.silver_customers_orders
group by aisle_name
sort by total_products desc
limit 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_products</th><th>aisle_name</th></tr></thead><tbody><tr><td>150609</td><td>fresh vegetables</td></tr><tr><td>150473</td><td>fresh fruits</td></tr><tr><td>78493</td><td>packaged vegetables fruits</td></tr><tr><td>55240</td><td>yogurt</td></tr><tr><td>41699</td><td>packaged cheese</td></tr><tr><td>36617</td><td>water seltzer sparkling water</td></tr><tr><td>32644</td><td>milk</td></tr><tr><td>31269</td><td>chips pretzels</td></tr><tr><td>26240</td><td>soy lactosefree</td></tr><tr><td>23635</td><td>bread</td></tr></tbody></table></div>

-- %%
/* Product Reorder Conversion Rate */
select
  count(reordered) / count(distinct op_product_id) as reorder_conversion_rate
from instacart.default.silver_customers_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>reorder_conversion_rate</th></tr></thead><tbody><tr><td>35.39138102906219</td></tr></tbody></table></div>

-- %%
/* Peak Demand Periods */
select
  order_dow,
  order_hour_of_day,
  count(orders_order_id) as orders_per_time_slot
from instacart.default.silver_customers_orders
group by order_dow, order_hour_of_day
order by orders_per_time_slot desc
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order